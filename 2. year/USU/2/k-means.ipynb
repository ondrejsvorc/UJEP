# %%
# Algoritmus K-means
# 1. Náhodné zvolení centroidů
# 2. Výpočet vzdálenosti každého bodu od každého centroidu
# 3. Označkování bodů do n množin, kde n je počet centroidů na základě toho, k jakému centroidu jsou nejblíže
# 4. Výpočet nových centroidů na základě průměrné hodnoty bodů v množinách
# 5. Opakovat do určité doby (Konvergence / Maximum iterací)
# 6. Znovuzvolení centroidů

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs


def k_means(X, k, max_iterations=1000):
    # 1. Náhodné zvolení centroidů
    centroids = X[np.random.choice(X.shape[0], k, replace=False)]

    # 2. Výpočet vzdálenosti každého bodu od každého centroidu
    for _ in range(max_iterations):
        distances = np.linalg.norm(X[:, np.newaxis] - centroids, axis=2)

        # 3. Označkování bodů do n množin, kde n je počet centroidů na základě toho, k jakému centroidu jsou nejblíže
        y = np.argmin(distances, axis=1)

        # 4. Výpočet nových centroidů na základě průměrné hodnoty bodů v množinách
        centroids_new = np.array([X[y == i].mean(axis=0) for i in range(k)])

        # 5. Opakovat do určité doby (Konvergence / Maximum iterací)
        if np.allclose(centroids, centroids_new):
            break

        # 6. Znovuzvolení centroidů
        centroids = centroids_new

    return centroids, y


X, y = make_blobs(n_samples=500, centers=5, n_features=2, random_state=0)
plt.scatter(X[:, 0], X[:, 1], c=y)
plt.grid()
plt.title("Body různých tříd v prostoru příznaků")
plt.show()
print(y)
print(set(y))

centroids, y = k_means(X, k=5)
plt.scatter(X[:, 0], X[:, 1], c=y, cmap="viridis", alpha=0.6)
plt.scatter(centroids[:, 0], centroids[:, 1], c="red", marker="X", s=200)
plt.grid()
plt.title("Algoritmus K-means")
plt.show()
print(y)
print(set(y))
# Out:
# [1 0 0 2 0 4 0 4 1 1 3 2 0 3 2 4 2 4 0 2 1 4 2 2 1 3 1 1 3 2 1 0 0 3 0 1 1
#  4 4 4 3 4 2 2 0 0 4 0 1 3 0 4 1 1 4 0 4 4 3 2 1 4 1 2 0 3 2 3 0 0 2 1 2 4
#  0 2 1 1 2 1 2 3 0 0 4 1 4 0 0 2 2 3 3 2 4 1 1 2 3 0 1 3 3 1 3 2 4 1 1 0 0
#  2 1 4 4 3 3 3 1 4 4 2 0 3 2 0 4 2 3 3 3 1 0 4 3 4 4 4 0 2 1 3 1 2 1 4 4 3
#  1 0 0 3 3 1 2 0 0 0 3 2 3 4 2 0 1 1 2 1 4 1 2 0 4 4 1 3 2 3 0 3 0 3 3 4 2
#  4 1 0 3 4 3 1 4 2 1 2 2 4 3 3 1 3 0 3 3 1 4 2 2 0 4 3 0 3 4 3 4 1 1 0 1 2
#  4 4 4 0 2 4 4 2 1 2 0 3 3 2 3 2 4 0 1 0 3 4 1 1 3 3 1 4 4 0 1 1 0 0 2 0 2
#  3 4 2 3 1 0 2 4 1 2 0 0 3 2 1 3 1 3 1 3 3 2 1 1 1 0 1 3 2 3 4 2 0 0 0 1 4
#  3 2 4 3 4 0 1 1 3 0 4 1 1 3 4 3 0 4 0 2 0 4 4 4 3 3 0 1 0 3 4 4 1 1 3 2 1
#  0 0 2 2 3 1 4 2 0 2 4 1 1 1 3 0 2 2 1 2 0 1 1 2 0 0 4 2 0 4 0 2 1 2 1 3 3
#  1 2 4 0 1 1 4 0 3 0 4 4 0 4 4 3 3 4 2 3 3 3 2 4 4 4 4 1 3 1 0 2 4 1 1 0 2
#  0 2 3 4 0 4 3 0 2 4 3 0 1 4 2 3 0 1 0 2 3 1 0 2 4 3 1 3 1 0 3 1 3 1 4 0 0
#  3 1 1 0 0 2 0 2 4 2 2 1 4 2 3 2 4 3 0 4 2 2 3 2 2 0 4 2 3 1 0 2 3 4 0 4 2
#  4 1 4 0 3 2 3 3 3 2 4 2 2 2 4 0 2 2 0]
# {0, 1, 2, 3, 4}
# [0 4 4 3 4 1 4 1 0 0 2 3 4 2 3 1 3 1 4 3 0 1 0 4 0 2 0 0 2 3 0 4 4 2 4 0 0
#  1 1 1 2 1 3 0 4 0 1 4 0 2 4 1 0 0 1 4 1 1 2 3 0 1 0 4 4 2 4 2 4 4 4 0 3 1
#  4 4 0 0 3 0 3 2 4 4 1 0 1 4 4 3 3 2 2 3 1 0 0 3 2 4 0 4 2 0 4 4 1 0 0 4 4
#  3 0 1 1 2 2 2 0 1 1 2 4 2 3 4 1 3 2 2 4 0 4 1 2 1 1 1 4 3 0 2 0 3 0 1 1 2
#  3 4 4 2 2 0 4 4 4 4 2 3 2 1 3 4 0 0 3 0 1 0 3 4 1 1 0 2 3 2 4 2 4 2 2 1 3
#  1 0 4 2 1 2 0 1 4 0 3 4 1 2 2 0 2 4 2 2 0 1 3 3 4 1 2 4 2 1 2 1 0 0 4 0 3
#  1 1 1 4 3 1 1 3 0 3 4 2 2 4 2 3 1 4 0 4 2 1 0 0 2 2 0 1 1 4 0 0 4 4 3 4 3
#  2 1 3 2 0 4 3 1 0 3 4 4 2 3 0 2 0 2 0 2 2 3 0 0 0 4 0 2 3 2 1 3 4 4 4 0 1
#  2 3 1 2 1 0 0 0 2 4 1 0 0 2 1 2 4 1 4 3 4 1 1 1 2 2 3 0 4 2 1 1 0 0 2 3 0
#  4 4 3 3 2 4 1 3 2 3 1 0 0 0 2 4 0 3 0 3 4 4 0 4 4 4 1 3 4 1 4 3 0 3 0 2 2
#  0 3 1 4 0 0 1 4 2 4 1 1 3 1 1 2 2 1 3 2 2 2 3 1 1 1 1 0 2 0 4 3 1 0 0 4 3
#  4 3 2 1 4 1 2 4 3 1 2 4 0 1 3 2 4 0 0 3 2 0 4 3 1 2 0 2 0 4 2 0 2 0 1 4 4
#  2 4 0 4 4 3 4 4 1 3 3 0 1 3 2 3 1 2 4 1 3 3 2 3 3 4 1 3 2 0 4 3 2 1 4 1 3
#  1 0 1 4 2 3 2 2 3 3 1 3 3 3 1 2 3 3 4]
# {0, 1, 2, 3, 4}
